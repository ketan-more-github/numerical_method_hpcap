# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = (12.0, 9.0)
# Preprocessing Input data
data = {'A': [4  , 5  , 5  , 6  , 7  , 8, 8  , 9],
        'B': [4.5, 4.5, 5.3, 5.7, 7.4, 8, 8.5, 8.5]}
data=pd.DataFrame.from_dict(data)
X = data.iloc[:, 0]
Y = data.iloc[:, 1]
plt.scatter(X, Y)
plt.show()
X_mean = np.mean(X)
Y_mean = np.mean(Y)
print(X_mean)
print(Y_mean)
num = 0
den = 0
print(len(X))
for i in range(len(X)):
    num += (X[i] - X_mean)*(Y[i] - Y_mean)
    den += (X[i] - X_mean)**2
    m = num / den
    c = Y_mean - m*X_mean
#print (m, c)
# Making predictions
    Y_pred = m*X + c
    plt.scatter(X, Y) # actual
    plt.plot([min(X), max(X)], [min(Y_pred), max(Y_pred)], color='red') # predicted
    plt.show()
# Out:
# 6.5
# 6.55
# 8

# %%
import numpy as np
from scipy.integrate import quad
import sympy as smp

x=1.5
f = 2+2*x+x**2+np.sin(2*np.pi*x) + np.cos((2*np.pi*x)/0.5 )

smp.integrate(f , )
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /home/hpcsap/Numrical_method/assignment/linear.ipynb Cell 2 line 8
#       <a href='vscode-notebook-cell:/home/hpcsap/Numrical_method/assignment/linear.ipynb#W1sZmlsZQ%3D%3D?line=4'>5</a> x=1.5
#       <a href='vscode-notebook-cell:/home/hpcsap/Numrical_method/assignment/linear.ipynb#W1sZmlsZQ%3D%3D?line=5'>6</a> f = 2+2*x+x**2+np.sin(2*np.pi*x) + np.cos((2*np.pi*x)/0.5 )
# ----> <a href='vscode-notebook-cell:/home/hpcsap/Numrical_method/assignment/linear.ipynb#W1sZmlsZQ%3D%3D?line=7'>8</a> smp.integrate(f)
#
# File /usr/lib/python3/dist-packages/sympy/integrals/integrals.py:1564, in integrate(meijerg, conds, risch, heurisch, manual, *args, **kwargs)
#    1400 """integrate(f, var, ...)
#    1401
#    1402 .. deprecated:: 1.6
#    (...)
#    1554
#    1555 """
#    1556 doit_flags = {
#    1557     'deep': False,
#    1558     'meijerg': meijerg,
#    (...)
#    1562     'manual': manual
#    1563     }
# -> 1564 integral = Integral(*args, **kwargs)
#    1566 if isinstance(integral, Integral):
#    1567     return integral.doit(**doit_flags)
#
# File /usr/lib/python3/dist-packages/sympy/integrals/integrals.py:96, in Integral.__new__(cls, function, *symbols, **assumptions)
#      86 if isinstance(function, Poly):
#      87     sympy_deprecation_warning(
#      88         """
#      89         integrate(Poly) and Integral(Poly) are deprecated. Instead,
#    (...)
#      93         deprecated_since_version="1.6",
#      94         active_deprecations_target="deprecated-integrate-poly")
# ---> 96 obj = AddWithLimits.__new__(cls, function, *symbols, **assumptions)
#      97 return obj
#
# File /usr/lib/python3/dist-packages/sympy/concrete/expr_with_limits.py:547, in AddWithLimits.__new__(cls, function, *symbols, **assumptions)
#     545 def __new__(cls, function, *symbols, **assumptions):
#     546     from sympy.concrete.summations import Sum
# --> 547     pre = _common_new(cls, function, *symbols,
#     548         discrete=issubclass(cls, Sum), **assumptions)
#     549     if isinstance(pre, tuple):
#     550         function, limits, orientation = pre
#
# File /usr/lib/python3/dist-packages/sympy/concrete/expr_with_limits.py:66, in _common_new(cls, function, discrete, *symbols, **assumptions)
#      64     free = function.free_symbols
#      65     if len(free) != 1:
# ---> 66         raise ValueError(
#      67             "specify dummy variables for %s" % function)
#      68     limits, orientation = [Tuple(s) for s in free], 1
#      70 # denest any nested calls
#
# ValueError: specify dummy variables for 8.25000000000000

# %%
import random
from datetime import datetime
dt = datetime.now()
random.seed(4)  #genrate same random values with seed 4
#random.seed(int(dt.strftime('%Y%m%d%H%M%S%f')))
for i in range(5):
    print(random.randint(0,10), end="\t")

# %% [markdown]
#                                 parallel random number genrator

# %%
import numpy as np
import matplotlib.pyplot as plt
mu = 100
sigma = 2
s = np.random.normal(mu , sigma  , 1000)
plt.hist(s , bins=25 , density=False , alpha=0.5)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
s= np.random.triangular(-3 , 0 , 8 , 1000)
plt.hist(s , bins=25 , density=False , alpha=0.6)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
s= np.random.uniform(-1 , 0 , 1000)
count, bins , ignored = plt.hist(s , 15 , density=True)
plt.plot(bins , np.ones_like(bins) , linewidth=2 , color='r')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
a=5
s= np.random.weibull(a,1000)
x=np.arange(1,100)/50
def weib(x,n,a):
    return(a/9)*(x/n)**(a-1)*np.exp(-(x/n)**a)

count, bins , ignored = plt.hist(np.random.weibull(5 ,1000))
x=np.arange(1,100)/50
scale = count.max()/weib(x,1,5).max()
plt.plot(x , weib(x ,1,5)*scale)
plt.show()
